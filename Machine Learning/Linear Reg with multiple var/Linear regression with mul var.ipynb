# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("house_dataset.csv")
df.head()
# Out:
#    Area  Bedrooms  Age   Price
# 0  1124         3   25  197400
# 1  2440         2   29  289000
# 2  2873         3   27  362300
# 3  1196         1   10  239600
# 4  1828         3    1  387800

# %%
df.shape
# Out:
# (100, 4)

# %%
df.columns
# Out:
# Index(['Area', 'Bedrooms', 'Age', 'Price'], dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(5,3))
plt.scatter(df.Bedrooms,df.Price)

# %%
plt.figure(figsize=(5,3))
plt.scatter(df.Age,df.Price)

# %%
corr_data = df.corr()
corr_data
# Out:
#               Area  Bedrooms       Age     Price
# Area      1.000000 -0.252484 -0.072651  0.745559
# Bedrooms -0.252484  1.000000  0.015491  0.135721
# Age      -0.072651  0.015491  1.000000 -0.629859
# Price     0.745559  0.135721 -0.629859  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(5,3))
sns.heatmap(corr_data, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

# %%
X = df.drop("Price", axis=1) #independent Features
X.head()
# Out:
#    Area  Bedrooms  Age
# 0  1124         3   25
# 1  2440         2   29
# 2  2873         3   27
# 3  1196         1   10
# 4  1828         3    1

# %%
y = df.Price # Dependent Feature

# %% [markdown]
# ![image.png](attachment:41854e8e-bf3d-4418-86cd-725a52c6176b.png)

# %% [markdown]
# ![image.png](attachment:3fe0a880-8c60-41db-996f-6cc92b9417aa.png)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=100)

# %%
X_train.shape, X_test.shape, y_train.shape,y_test.shape
# Out:
# ((80, 3), (20, 3), (80,), (20,))

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X.head()
# Out:
#    Area  Bedrooms  Age
# 0  1124         3   25
# 1  2440         2   29
# 2  2873         3   27
# 3  1196         1   10
# 4  1828         3    1

# %%
model.predict([[1200,2,10]])
# Out:
# C:\Users\HP\anaconda3\envs\ml\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([259999.99999998])

# %%
model.coef_
# Out:
# array([  100., 20000., -5000.])

# %%
model.intercept_
# Out:
# 149999.99999996193

# %%
model.score(X_train,y_train) # Training data  accracy -> R-square
# Out:
# 1.0

# %%
model.score(X_test,y_test) # Test data accuracy
# Out:
# 1.0
